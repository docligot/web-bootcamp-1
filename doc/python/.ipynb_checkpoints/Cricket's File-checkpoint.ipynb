# %%
import pandas as pd

# %%
xlsx = pd.ExcelFile(r"D:\htdocs\web-bootcamp-1\doc\python\datalog_thursdays.xlsx")
df = pd.read_excel(xlsx, "Sheet2")

# %%
import time
import datetime
s = "01/12/2011"
time.mktime(datetime.datetime.strptime(s, "%d/%m/%Y").timetuple())
# Out:
# 1322668800.0

# %%
def into_time(x):
    y = time.mktime(datetime.datetime.strptime(x, "%H:%M:%S").timetuple())
    return y

# %%
s = "2019-10-03"
time.mktime(datetime.datetime.strptime(s, "%y-%m-%d").timetuple())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7b72eb97be6c> in <module>()
#       1 s = "2019-10-03"
# ----> 2 time.mktime(datetime.datetime.strptime(s, "%y-%m-%d").timetuple())
#
# ~\Anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# ~\Anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
#
# ...

# %%
df
# Out:
#                       Source.Name  TIME raw      TIME  DATE raw  HOUR  \
# 0     Datalog_03102019_075950.txt     75950  07:59:50   3102019     7
# 1     Datalog_17102019_075955.txt     75955  07:59:55  17102019     7
# 2     Datalog_28112019_075833.txt     75833  07:58:33  28112019     7
# 3     Datalog_05122019_075907.txt     75907  07:59:07   5122019     7
# 4     Datalog_02012020_075950.txt     75950  07:59:50   2012020     7
# 5     Datalog_01082019_080240.txt     80240  08:02:40   1082019     8
# 6     Datalog_08082019_080209.txt     80209  08:02:09   8082019     8
# 7     Datalog_22082019_080042.txt     80042  08:00:42  22082019     8
# 8     Datalog_29082019_080131.txt     80131  08:01:31  29082019     8
# 9     Datalog_05092019_080009.txt     80009  08:00:09   5092019     8
# 10    Datalog_12092019_082000.txt     82000  08:20:00  12092019     8
# 11    Datalog_19092019_080147.txt     80147  08:01:47  19092019     8
# ...
