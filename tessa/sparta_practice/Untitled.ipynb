# %%
import pandas as pd

# %%
df = pd.read_excel('SPARTA MOOCs Detailed Timeline.xlsx', sheet_name='Input')

# %%
df
# Out:
#                                          Course  \
# 0                 Getting Grounded on Analytics
# 1                 Getting Grounded on Analytics
# 2                 Getting Grounded on Analytics
# 3                 Getting Grounded on Analytics
# 4                 Getting Grounded on Analytics
# ..                                          ...
# 121  Analytics Applications in Finance and Risk
# 122  Analytics Applications in Finance and Risk
# 123  Analytics Applications in Finance and Risk
# 124  Analytics Applications in Finance and Risk
# 125  Analytics Applications in Finance and Risk
#
#                                    Tasks Target Start Date Target End Date  \
# 0                         SME Onboarding        2019-11-25      2019-12-06
# 1    Documentary Requirements Completion        2019-11-29      2019-12-19
# 2        Video Content Production Shoots        2019-12-20      2020-01-07
# 3          Video Content Post-production        2020-01-08      2020-01-31
# ...
